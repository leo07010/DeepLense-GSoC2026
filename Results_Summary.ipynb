# %% [markdown]
# # DeepLense GSoC 2026 — Results Summary
#
# ## Test I: Classical CNN (ResNet-18)
# - **Val Accuracy:** 91.67%
# - **Macro AUC:** 0.9838
# - **Per-class AUC:** no=0.9938, sphere=0.9714, vort=0.9862
#
# ## Test III: Quantum ML (CUDA-Q)
# Multiple approaches explored:
#
# | Model | Val Accuracy | Macro AUC | Description |
# |-------|-------------|-----------|-------------|
# | CNN+VQC | Best | Best | Pre-trained CNN features → 16-qubit VQC |
# | VQC (PCA) | ~40% | ~0.50 | PCA features → 16-qubit VQC |
# | QCNN 8×8 | ~34% | ~0.53 | Quantum Conv layer (e2e, SPSA) |

# %% [markdown]
# ## CNN ROC Curve

# %%
# CNN ROC curve output

# %% [markdown]
# ## VQC ROC Curve

# %%
# VQC ROC curve output
